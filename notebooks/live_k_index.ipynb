# %% [markdown]
# # Live K Index
# In this tutorial we demonstrate the live K index functionality.
#
# - We make use of the live_k and plot_k functions to quickly load and plot the most up to date version of the k index for the chosen site. We use 'dun' for Dunsink in this example.
#
# - We set the time using pandas to get the current time other times can be used to plot historic live K index plots as they would have been seen at the time
#
# - live_k returns a dataframe with the live K index values and plot_k produces a simple bar chart from the dataframe returning the figure and subplot axes for further manipulation

# %%
from magie import live_k, plot_k
from magie.k_index import _load_default_site_thresholds
import pandas as pd
now_time= pd.Timestamp.now()
plot_k(live_k(now_time, site_code='dun'))
# Out:
# Downloading: 100.00% [4571136/4567897 bytes]
# Download complete!
# Downloading: 100.00% [4571136/4568018 bytes]
# Download complete!
# Downloading: 100.00% [4571136/4563725 bytes]
# Download complete!
# Downloading: 100.00% [4571136/4563460 bytes]
# Download complete!
# Downloading: 100.00% [2613248/2609403 bytes]
# Download complete!
# /home/simon/anaconda3/envs/MARTAS/lib/python3.7/site-packages/matplotlib/axes/_base.py:2480: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# (<Figure size 3000x1500 with 2 Axes>, <AxesSubplot:>, <AxesSubplot:>)

# %% [markdown]
# ## From Local Example
# Live K can also be calculated from a local store of the data. Here we show an example using an EZIE Mag (raspberry pi magnetometer) at Dunsink

# %%
from magie import live_k, plot_k
import pandas as pd
now_time= pd.Timestamp('2025-02-24')
path_prefix='./EZIE_Mag/magnetometer_archive/'
plot_k(live_k(now_time, 'dun_eziemag', path_prefix=path_prefix))
# Out:
# /home/simon/anaconda3/envs/MARTAS/lib/python3.7/site-packages/matplotlib/axes/_base.py:2480: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# (<Figure size 3000x1500 with 2 Axes>, <AxesSubplot:>, <AxesSubplot:>)

# %%
from magie import live_k, plot_k
import pandas as pd
now_time= pd.Timestamp.now()
plot_k(live_k(now_time, site_code='val'))
# Out:
# Downloading: 100.00% [81920/73819 bytes]
# Download complete!
# Downloading: 100.00% [81920/73767 bytes]
# Download complete!
# Downloading: 100.00% [81920/73819 bytes]
# Download complete!
# Downloading: 100.00% [81920/73819 bytes]
# Download complete!
# Downloading: 100.00% [49152/43269 bytes]
# Download complete!
# /home/simon/anaconda3/envs/MARTAS/lib/python3.7/site-packages/matplotlib/axes/_base.py:2480: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# (<Figure size 3000x1500 with 2 Axes>, <AxesSubplot:>, <AxesSubplot:>)
